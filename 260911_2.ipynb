# %%
print("2주차")
print(10 + 20)
# Out:
# 2주차
# 30

# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 25, 40],
    'City': ['New York', 'Paris', 'London', 'Tokyo']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   25    London
# 3    David   40     Tokyo

# %%
print(1+2)
# Out:
# 3

# %%
a = 1
b = 2
print(a+b)
# Out:
# 3

# %%
# 두 자연수 10과 5가 주어질 때, A+B, A-B, A*B, A/B를 출력하는 프로그램 작성

# %%
A = 10
B = 5

print(A+B)
print(A-B)
print(A*B)
print(A/B)
# Out:
# 15
# 5
# 50
# 2.0

# %%
# 가로 12, 세로 7인 직사각형의 넓이와 둘레

# %%
n = 12
w = 7

len = (n+w)*2
area = n*w

print(len)
print(area)
# Out:
# 38
# 84

# %%
# 국어 88, 영어 92, 수학 75인 학생의 과목 평균

# %%
kor = 88
eng = 92
math = 75

avg = (kor+eng+math)/3
print(avg)
# Out:
# 85.0
